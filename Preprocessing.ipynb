# %%
import cv2
import skimage
import numpy as np
import os
from importantImageFunctions import *

# %%
images = []

padding = 50
img = skimage.io.imread("./imgs/paper.jpg")[padding:-padding, padding:-padding]
gray = imageToBinary(removeShadowsFromPaper(img))
gray = removeBlank(gray)
images.append(gray)
# if needed
# lines = getTextLinesFromBinary(gray)
# if needed
# chars = extractCharactersFromBinaryImage(gray)

show_images(images)
# Out:
# /home/kali/miniconda3/lib/python3.9/site-packages/skimage/util/dtype.py:541: UserWarning: Downcasting int64 to uint8 without scaling because max value 255 fits in uint8
#   return _convert(image, np.uint8, force_copy)
